# %%
from Color_analyzer import Color_analyzer

# %%
myanalyzer = Color_analyzer()

# %%
pic_dir = "G://photos//2017-5-12//"
feature = myanalyzer.feature_extractor(pic_dir, pic_format='JPG', zoom_in_size=10)
# Out:
# There are 131 picture(s).
# 100%|████████████████████████████████████████████████████████████████████████████████| 130/130 [02:17<00:00,  1.05s/it]
# Extraction completed.

# %%
myanalyzer.plot_3d(feature)

# %%
myanalyzer.plot_hist(feature)
